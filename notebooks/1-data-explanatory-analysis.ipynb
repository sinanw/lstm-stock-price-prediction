# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 1 - Data Explanatory Analysis
# In this notebook, we load the raw data file containing the historical daily prices of Google stocks and explore it to select a specific period for analysis/prediction.
#
# > **INPUT**: The raw data file of all available stock prices for Google, as downloaded from its original source. <br/>
# > **OUTPUT**: The data of the targeted period for analysis, stored in an intermediary location for next steps.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. LOAD DATASET FILE

# %% [markdown]
# The dataset we are going to initially load and explore is the historical records of daily price details of Google (Alphabet Inc.) sourced from [Yahoo Finance](https://finance.yahoo.com/quote/GOOG).
#
# At first, we load the whole dataset available, which covers the period from 2004-08-19 until the time of creating this script 2024-04-04.
#
# The main objective of loading the entire dataset is to choose a particular time frame for analysis.

# %%
# Prepare data file location and load the dataset
data_file_location = "..\\data\\raw\\"
data_file_name = "google_stock_price_full"
data_file_ext = "csv"

# Load data file
data = pd.read_csv(data_file_location + data_file_name + "." + data_file_ext)

# %%
# Check dataset shape
data.shape
# Out:
# (4940, 7)

# %%
# Check dataset head
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.499133  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.697639  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.724787  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.611960  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.640104  184645512

# %%
# Check data types
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ### 3. INITIAL DATA CLEANING

# %% [markdown]
# As we notice, the Data column is currently in a String format which requires conversion to proper Datetime format.

# %%
# Convert Date column to a valid Datetime format
data["Date"] = pd.to_datetime(data["Date"])

# %%
# Check column format
data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# ### 4. EXPLORE DATASET

# %%
# Plot the open and close price for the whole period
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
plt.plot(data["Date"], data["Open"])
plt.xlabel("Time")
plt.ylabel("Open Price (USD)")
plt.title("Google Open Stock Price")

plt.subplot(1,2,2)
plt.plot(data["Date"], data["Close"])
plt.xlabel("Time")
plt.ylabel("Close Price (USD)")
plt.title("Google Close Stock Price")

plt.suptitle("Google Stock Price Over Time")
plt.show()

# %% [markdown]
# The previous charts show an inconsistent behavior in the stock's performance over time, with a completely distinct trend during the past five years.
#
# This means that the old historical data might not be relevant to the predictions, since it represents a different period with outdated indicators.
#
# Accordingly, we will concentrate our analysis on the most recent five-year data, as it is expected to provide more accurate insights for predicting future trends.

# %%
# Select stock price records for the last five years, starting from 2019
data_5years = data[data["Date"].dt.year >= 2019]

# Check filtered data shape
data_5years.shape
# Out:
# (1323, 7)

# %%
# Plot open stock price performance in the last five years
plt.figure(figsize=(18,6))
plt.plot(data_5years["Date"], data_5years["Open"])
plt.xlabel("Time")
plt.ylabel("Stock Price (USD)")
plt.title("Google Open Stock Price - Starting From 2019")
# Out:
# Text(0.5, 1.0, 'Google Open Stock Price - Starting From 2019')

# %% [markdown]
# The selected period seems to be more relevant for analysis, as it's more likely to drive the stock performance in future in addition to other external factors.

# %% [markdown]
# ### 5. STORE FILTERED DATASET

# %%
# Prepare data file location
data_file_location = "..//data//interim//"
data_file_name = "google_stock_price_recent"
data_file_ext = "csv"

# Store dataset
data_5years.to_csv(data_file_location + data_file_name + "." + data_file_ext, index=None)
